# %%
# %matplotlib inline

# %%
import pandas as pd

df = pd.read_csv('tips.csv')
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
df.plot()

# %%
df.plot(subplots=True)
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x7f3a0d53cf28>,
# ...
#       dtype=object)

# %%
df.sort_values('total_bill', inplace=True)
df.head()
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 67         3.07  1.00  Female    Yes   Sat  Dinner     1
# 92         5.75  1.00  Female    Yes   Fri  Dinner     2
# 111        7.25  1.00  Female     No   Sat  Dinner     1
# 172        7.25  5.15    Male    Yes   Sun  Dinner     2
# 149        7.51  2.00    Male     No  Thur   Lunch     2

# %%
df.total_bill.plot()

# %%
df.total_bill.plot(use_index=False)

# %%
ttdf = df[['total_bill', 'tip']]
ttdf.plot(use_index=False)

# %%
ttdf.plot(use_index=False, xlim=(235, 245))

# %% [markdown]
# style
#
# - [color](https://matplotlib.org/api/colors_api.html)
# - [marker](https://matplotlib.org/api/markers_api.html)
# - [line style](https://matplotlib.org/gallery/lines_bars_and_markers/line_styles_reference.html) - -- -. :
#
# remember playstation gamepad
#
# rgbm
# o^xs
#
# ![](https://upload.wikimedia.org/wikipedia/commons/thumb/d/d5/PlayStation_3_gamepad.svg/500px-PlayStation_3_gamepad.svg.png)

# %%
ttdf.plot(use_index=False, xlim=(235, 245), style=['ro-', 'g^:'])

# %%
day_count = df['day'].value_counts()
day_count
# Out:
# Sat     87
# Sun     76
# Thur    62
# Fri     19
# Name: day, dtype: int64

# %%
day_count.plot.bar()

# %%
day_count.plot.barh()

# %%
day_count.plot.barh(color=['b', '0.75', '#00ff00', 'r'])

# %%
df.groupby('day').mean()
# Out:
#       total_bill       tip      size
# day
# Fri    17.151579  2.734737  2.105263
# Sat    20.441379  2.993103  2.517241
# Sun    21.410000  3.255132  2.842105
# Thur   17.682742  2.771452  2.451613

# %%
df.groupby('day').mean().plot.bar()

# %%
df.groupby('day').mean().drop('size', axis=1).plot.bar()

# %%
df.groupby(['day', 'time']).size()
# Out:
# day   time
# Fri   Dinner    12
#       Lunch      7
# Sat   Dinner    87
# Sun   Dinner    76
# Thur  Dinner     1
#       Lunch     61
# dtype: int64

# %%
_.unstack()
# Out:
# time  Dinner  Lunch
# day
# Fri     12.0    7.0
# Sat     87.0    NaN
# Sun     76.0    NaN
# Thur     1.0   61.0

# %%
_.plot.bar()

# %%
df['tip'].plot.hist(bins=10)

# %%
df.plot.scatter(x='total_bill', y='tip')

# %%
df.corr()
# Out:
#             total_bill       tip      size
# total_bill    1.000000  0.675734  0.598315
# tip           0.675734  1.000000  0.489299
# size          0.598315  0.489299  1.000000

# %%
df_m = df[df.sex == 'Male']
df_w = df[df.sex == 'Female']

# %%
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(10,6))

for i in range(1, 7):
    plt.subplot(3, 2, i)  # row, col, index
    df.tip.plot.hist(bins=i)

# %%
ax = df_m.plot.scatter(  x='total_bill', y='tip', c='b', alpha=0.3)
df_w.plot.scatter(ax=ax, x='total_bill', y='tip', c='r', alpha=0.3)

# %%
df.groupby(['day','time']).size()
# Out:
# day   time
# Fri   Dinner    12
#       Lunch      7
# Sat   Dinner    87
# Sun   Dinner    76
# Thur  Dinner     1
#       Lunch     61
# dtype: int64

# %%
df.groupby(['day','time']).size().unstack()
# Out:
# time  Dinner  Lunch
# day
# Fri     12.0    7.0
# Sat     87.0    NaN
# Sun     76.0    NaN
# Thur     1.0   61.0

# %%
_.plot(kind='bar')

# %%
df.groupby(['day']).sum()
# Out:
#       total_bill     tip  size
# day
# Fri       325.88   51.96    40
# Sat      1778.40  260.40   219
# Sun      1627.16  247.39   216
# Thur     1096.33  171.83   152

# %%
_[['total_bill', 'tip']].plot(kind='bar')
